# %%
#lets import in the libraries
import pandas as pd
import matplotlib.cm as cmx
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
import seaborn as sns; sns.set()
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols    
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
data=pd.read_csv("merged_data_3.csv",encoding="latin-1")

# %%
dataReplace=data.replace("-",np.nan)

# %%
dataReplace.head()
# Out:
#    Unnamed: 0      Country  Year School age population (thousands)  \
# 0           0  Afghanistan  2016                       13299.24707
# 1           1      Algeria  2016                       8512.623047
# 2           2      Andorra  2016                               NaN
# 3           3    Argentina  2016                       10821.82813
# 4           7    Australia  2016                       4197.949219
#
#          urban  pre-primary      primary    secondary NWA_Basic water service  \
# 0  27.13200188  15.83112907  45.34436417  38.82450485                       0
# 1  71.30400085  10.01031017  42.57013321  47.41955566             93.30671292
# 2          NaN          NaN          NaN          NaN                     100
# 3  91.89299774  20.48494911  40.30799484  39.20705414                       0
# 4  89.55399323  7.541897297  51.23599625  41.22210693                     100
#
#   NWA_Limited water service  ... PH_Basic hygiene service  \
# ...

# %%
dataReplace.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Year', 'School age population (thousands)',
#        'urban', 'pre-primary', 'primary', 'secondary',
#        'NWA_Basic water service', 'NWA_Limited water service',
#        'NWA_No water service', 'UWA_Basic water service',
#        'UWA_Limited water service', 'UWA_No water service',
#        'RWA_Basic water service ', 'RWA_Limited water service ',
#        'RWA_No water service ', 'PPWA_Basic water service ',
#        'PPWA_Limited water service ', 'PPWA_No water service ',
#        'PWA_Basic water service', 'PWA_Limited water service ',
#        'PWA_No water service ', 'SWA_Basic water service ',
#        'SWA_Limited water service ', 'SWA_No water service',
#        'NS_Basic sanitation service', 'NS_Limited sanitation service',
#        'NS_No sanitation service ', 'US_Basic sanitation service',
#        'US_Limited sanitation service', 'US_No sanitation service ',
#        'RS_Basic sanitation service', 'RS_Limited sanitation service',
# ...

# %%
Usedata=dataReplace[['NWA_Basic water service','NS_Basic sanitation service','NH_Basic hygiene service', 'Value' ]]

# %%
Usedata.shape
# Out:
# (147, 4)

# %%
#The relationship between water, sanication, hygeine---person  oorecoeff

# %%
UsedataValid=Usedata.dropna()

# %%
UsedataValid.shape
# Out:
# (38, 4)

# %%
print(UsedataValid)
# Out:
#     NWA_Basic water service NS_Basic sanitation service  \
# 5                       100                         100
# 6                       100                         100
# 7               73.63671704                 58.55357143
# 8                       100                         100
# 15                        0                 83.90410959
# 16              52.56573529                 70.43392955
# 17              41.59394997                 47.87229332
# 19                        0                       38.85
# 26                      100                         100
# 27                     55.2                        61.4
# 40               50.5246315                 82.72727273
# 52                     73.8                     60.2952
# 58              10.03837335                           0
# 60              58.62468394                 81.53165867
# 61                      100                 91.91586998
# 63                    65.69                       34.12
# ...

# %%
type(UsedataValid)
# Out:
# pandas.core.frame.DataFrame

# %%
print(UsedataValid)
# Out:
#     NWA_Basic water service NS_Basic sanitation service  \
# 5                       100                         100
# 6                       100                         100
# 7               73.63671704                 58.55357143
# 8                       100                         100
# 15                        0                 83.90410959
# 16              52.56573529                 70.43392955
# 17              41.59394997                 47.87229332
# 19                        0                       38.85
# 26                      100                         100
# 27                     55.2                        61.4
# 40               50.5246315                 82.72727273
# 52                     73.8                     60.2952
# 58              10.03837335                           0
# 60              58.62468394                 81.53165867
# 61                      100                 91.91586998
# 63                    65.69                       34.12
# ...

# %%
len(UsedataValid)
# Out:
# 38

# %%
#change the datatype into float
new_d=pd.DataFrame(UsedataValid,dtype=np.float)

# %%
print(new_d)
# Out:
#      NWA_Basic water service  NS_Basic sanitation service  \
# 5                 100.000000                   100.000000
# 6                 100.000000                   100.000000
# 7                  73.636717                    58.553571
# 8                 100.000000                   100.000000
# 15                  0.000000                    83.904110
# 16                 52.565735                    70.433930
# 17                 41.593950                    47.872293
# 19                  0.000000                    38.850000
# 26                100.000000                   100.000000
# 27                 55.200000                    61.400000
# 40                 50.524631                    82.727273
# 52                 73.800000                    60.295200
# 58                 10.038373                     0.000000
# 60                 58.624684                    81.531659
# 61                100.000000                    91.915870
# ...

# %%
#Pearson Coefficient
new_d.corr(method='pearson')
# Out:
#                                NWA_Limited water service  \
# NWA_Limited water service                       1.000000
# NS_Limited sanitation service                   0.110481
# NH_Limited hygiene service                      0.430885
# Value                                          -0.235524
#
#                                NS_Limited sanitation service  \
# NWA_Limited water service                           0.110481
# NS_Limited sanitation service                       1.000000
# NH_Limited hygiene service                          0.315514
# Value                                              -0.489173
#
#                                NH_Limited hygiene service      Value
# NWA_Limited water service                         0.430885 -0.235524
# NS_Limited sanitation service                     0.315514 -0.489173
# NH_Limited hygiene service                        1.000000 -0.233648
# Value                                            -0.233648  1.000000

# %%
Person=new_d.corr(method='pearson')

# %%
UsedataValid.to_csv('PearsonCorr.csv')

# %%
#PictureDraw

# %%
from pyecharts import options as opts
from pyecharts.charts import HeatMap
from pyecharts.render import make_snapshot
from snapshot_selenium import snapshot

# %%
heatmap=HeatMap()
rowdata=['NWA','NS','NH','Value']
columndata=['Value','NH','NS','NWA']
Personvalue = [[0,0,-0.235524],[0,1,-0.489173],[0,2,-0.2336],[0,3,1],[1,0,0.430885],[1,1,0.3155],[1,2,1],[1,3,-0.2336],[2,0,0.11048],[2,1,1],[2,2,0.3155],[2,3,-0.4891],[3,0,1],[3,1,0.11048],[3,2,0.4308],[3,3,-0.2355]]
heatmap.add_xaxis(
                  rowdata
                  )
heatmap.add_yaxis(
                 "Factors",
                  columndata, 
                  Personvalue,
                  label_opts=opts.LabelOpts(is_show=True,font_size=14,position="inside",font_family="Times New Roman"),
                  )
heatmap.set_global_opts(
            yaxis_opts=opts.AxisOpts(
                name="Candidate Factors",
                name_location="center",
                # 坐标轴名称的文字样式--刻度和名称
                axislabel_opts=opts.LabelOpts(font_family="Times New Roman"),
                
                name_textstyle_opts=opts.TextStyleOpts(font_size=18,font_family="Times New Roman"),
                name_gap=25,
                
                axistick_opts=opts.AxisTickOpts(
                is_inside=True,
                ),
            ),
            xaxis_opts=opts.AxisOpts(
                name="Candidate Factors",
                name_location="center",
                # 坐标轴名称的文字样式--刻度和名称
                axislabel_opts=opts.LabelOpts(font_family="Times New Roman"),
                
                name_textstyle_opts=opts.TextStyleOpts(font_size=18,font_family="Times New Roman"),
                name_gap=15,
                
                axistick_opts=opts.AxisTickOpts(
                is_inside=True,
                ),
            ),
         
            visualmap_opts=opts.VisualMapOpts(type_="color",min_=-1,max_=1, pos_right=20),
            
)
make_snapshot(snapshot, heatmap.render(path=r"C:\Users\20194289\Desktop\DataScience\OneDrive_1_2019114\OneDrive_2_2019117\Heapmap2.html"),"C:\\Users\\20194289\\Desktop\\DataScience\\OneDrive_1_2019114\\OneDrive_2_2019117\\Heapmap2.pdf",pixel_ratio=10)

# %%
Usedata2=dataReplace[['Country','NWA_Limited water service','NS_Limited sanitation service','NH_Limited hygiene service ', 'Value' ]]

# %%
from pyecharts.charts import Scatter
import execjs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-110-7dff910bf687> in <module>
#       1 from pyecharts.charts import Scatter
# ----> 2 import execjs
#
# ModuleNotFoundError: No module named 'execjs'

# %%
# !conda install PyExecJs
#只支持python2
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pyexecjs
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/win-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
Scatter1=Scatter()
Scatter1.add_xaxis(Usedata2['NWA_Limited water service'])
Scatter1.add_yaxis("Value", 
                  ),
Scatter1.set_global_opts(
            title_opts=opts.TitleOpts(title="Scatter-VisualMap(Color)"),
            visualmap_opts=opts.VisualMapOpts(max_=150),)

# %%
make_snapshot(snapshot, Scatter1.render(path=r"C:\Users\20194289\Desktop\DataScience\OneDrive_1_2019114\OneDrive_2_2019117\Scatter.html"),"C:\\Users\\20194289\\Desktop\\DataScience\\OneDrive_1_2019114\\OneDrive_2_2019117\\Scatter.pdf",pixel_ratio=10)

# %%
#Regression  Water===
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
X=new_d[['NH_Basic hygiene service','NS_Basic sanitation service', 'Value']]

# %%
Y=new_d['NWA_Basic water service']

# %%
X=sm.add_constant(X)
est=sm.OLS(Y,X).fit()
est.summary()
# Out:
# C:\Users\20194289\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     NWA_Basic water service   R-squared:                       0.499
# Model:                                 OLS   Adj. R-squared:                  0.455
# Method:                      Least Squares   F-statistic:                     11.31
# Date:                     Fri, 08 Nov 2019   Prob (F-statistic):           2.68e-05
# Time:                             10:07:15   Log-Likelihood:                -176.12
# No. Observations:                       38   AIC:                             360.2
# Df Residuals:                           34   BIC:                             366.8
# ...

# %%
Usedata2=dataReplace[['NWA_Limited water service','NS_Limited sanitation service','NH_Limited hygiene service ', 'Value' ]]

# %%
UsedataValid2=Usedata2.dropna()

# %%
UsedataValid2.shape
# Out:
# (28, 4)

# %%
new_d2=pd.DataFrame(UsedataValid2,dtype=np.float)

# %%
#Regression
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
X2=new_d2[['NH_Limited hygiene service ','NS_Limited sanitation service', 'Value']]

# %%
Y2=new_d2['NWA_Limited water service']

# %%
X2=sm.add_constant(X2)
est=sm.OLS(Y2,X2).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     NWA_Limited water service   R-squared:                       0.215
# Model:                                   OLS   Adj. R-squared:                  0.117
# Method:                        Least Squares   F-statistic:                     2.190
# Date:                       Fri, 08 Nov 2019   Prob (F-statistic):              0.115
# Time:                               10:28:43   Log-Likelihood:                -127.99
# No. Observations:                         28   AIC:                             264.0
# Df Residuals:                             24   BIC:                             269.3
# Df Model:                                  3
# Covariance Type:                   nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Regression hygie===
import pandas as pd
import numpy as np
import statsmodels.api as sm
X=new_d[['NWA_Basic water service','NS_Basic sanitation service', 'Value']]
Y=new_d['NH_Basic hygiene service']
X=sm.add_constant(X)
est=sm.OLS(Y,X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     NH_Basic hygiene service   R-squared:                       0.619
# Model:                                  OLS   Adj. R-squared:                  0.586
# Method:                       Least Squares   F-statistic:                     18.43
# Date:                      Fri, 08 Nov 2019   Prob (F-statistic):           2.84e-07
# Time:                              11:33:14   Log-Likelihood:                -176.38
# No. Observations:                        38   AIC:                             360.8
# Df Residuals:                            34   BIC:                             367.3
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Regression hygie===
import pandas as pd
import numpy as np
import statsmodels.api as sm
X=new_d[['NWA_Basic water service','NH_Basic hygiene service', 'Value']]
Y=new_d['NS_Basic sanitation service']
X=sm.add_constant(X)
est=sm.OLS(Y,X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     NS_Basic sanitation service   R-squared:                       0.553
# Model:                                     OLS   Adj. R-squared:                  0.513
# Method:                          Least Squares   F-statistic:                     14.01
# Date:                         Fri, 08 Nov 2019   Prob (F-statistic):           4.14e-06
# Time:                                 11:34:16   Log-Likelihood:                -168.93
# No. Observations:                           38   AIC:                             345.9
# Df Residuals:                               34   BIC:                             352.4
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Regression hygie===
import pandas as pd
import numpy as np
import statsmodels.api as sm
X=new_d[['NWA_Basic water service','NH_Basic hygiene service','NS_Basic sanitation service' ]]
Y=new_d['Value']
X=sm.add_constant(X)
est=sm.OLS(Y,X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     8.208
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):           0.000304
# Time:                        11:34:34   Log-Likelihood:                -158.17
# No. Observations:                  38   AIC:                             324.3
# Df Residuals:                      34   BIC:                             330.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...
